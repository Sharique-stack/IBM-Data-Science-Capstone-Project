# %% [markdown]
# # Solving a problem - Where and how to open a restaurant in Toronto

# %% [markdown]
# <img href="https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQR30NY_BhgnyVg-mCmdrINMqs4ihiZ1RDq_A&usqp=CAU"/>

# %% [markdown]
# <img href="https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQR30NY_BhgnyVg-mCmdrINMqs4ihiZ1RDq_A&usqp=CAU"/>

# %% [markdown]
# <img href="https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQR30NY_BhgnyVg-mCmdrINMqs4ihiZ1RDq_A&usqp=CAU"/>

# %% [markdown]
# <b>Opening a restaurant is about having a clear concept and brand then again how does a data science professional come up with a problem statament and solving it altogether is - is the area most suitable bringing into action the peace of mind while sitting at someone's place and restaurantiers have a stress-free lease or rent. Is there other successful business (here, restaurant) too at the roadside or there is a prospective concept down the road. Utter focus is on the former.</b>

# %% [markdown]
# Note : the target audience can be any investor who wants to start a retaurant in Toronto with couple of options at hand.

# %% [markdown]
# "Notional truth prevails logic", a place which is habitual of housing failed business should be avoided. A place which is crime prone area can never make a diner comfortable. And this is the part where I will apply machine learning algorithm and analytics by bringing Toronto police CSI data according to neighborhood.

# %% [markdown]
# ## Data - on which I will use analytics and k-means clustering will be brought in from several sources as is entailed further. Reference - https://data.torontopolice.on.ca/datasets/mci-2014-to-2019
# ## Rentals.ca  for best suited rentals/lease
# ## CMHC for hike prone neighborhoods. A hike in near future pertains to use optimum plan beforehand.
# ## Then I will use Foursquare API to see whether there's similar business near the house.

# %% [markdown]
# <b>The combined methodology will get us to conclusion where in Toronto can we rent a house for business or furthermore where in any place of the world someone should rent a lease for retaurantiering.</b>

# %% [markdown]
# # <font color=red>              Conclusion</font>

# %% [markdown]
# ### A place which is most optimum for opening a restaurant business is a potion made by forllowing-

# %% [markdown]
# * Lesser crime rate
# * No sign of unprecedented rental hike.
# * A similar business by the roadside makes for a bounty.
# * Best suited rental agreement
# * No history of several failed businesses of similar type in the house.
